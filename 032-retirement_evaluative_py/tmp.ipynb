# %%
import pandas as pd
from equity import Equity
a = Equity("sp_data.csv", "1971.12", "2017.12",100)
a.calculate_plan()
# Out:
# [100,
#  207.14523470724959,
#  318.7849515068768,
#  427.92361809304606,
#  541.6094062974745,
#  650.9147097957325,
#  748.3799700763744,
#  854.73737674794,
#  952.945823774063,
#  1091.4291281273333,
#  1180.7574514365335,
#  1288.199168770146,
#  1458.263446645565,
#  1594.4281525749243,
#  1715.2494599613037,
#  1763.4221492471163,
#  1844.8343647567672,
#  1919.875542446337,
#  1975.755428123013,
#  2041.6433861911169,
#  2171.39745925807,
#  2241.0783245303855,
#  2390.786540074121,
#  2596.9431394662543,
#  2524.6097697500036,
#  2458.4721207746325,
#  2607.9072869869224,
#  2651.3717784224405,
#  2880.0657650836088,
#  2849.5407343479123,
#  2880.459948387734,
#  3001.360414330213,
#  2769.872610996467,
#  2773.8168343253756,
#  2605.105811293507,
#  2774.499005533397,
#  2985.687666275845,
#  2912.3746630509618,
#  3273.255871444782,
#  3736.203932876756,
#  4031.8748039849543,
#  4202.0876177728305,
#  4593.695421548213,
#  4836.711174943528,
#  4967.9712387356185,
# ...

# %%
from bond import Bond
b = Bond("bond_data.csv","1970.01","2017.05",100)
b.calculate_plan()
# Out:
# [100,
#  200.64916666666664,
#  301.8597499722222,
#  403.63820699914186,
#  506.12394562391154,
#  609.4601459654825,
#  713.441952252457,
#  817.8771830556265,
#  923.0093623793006,
#  1028.6935617026197,
#  1134.9771648753533,
#  1241.446534715143,
#  1348.0572375125012,
#  1457.5671351475662,
#  1567.488581144026,
#  1677.4341519044601,
#  1788.0836861591295,
#  1900.1052317879269,
#  2012.9291368806414,
#  2126.718314456647,
#  2240.8798198809177,
#  2354.8456549593084,
#  2468.9825172375654,
#  2583.436507591857,
#  2698.7029896668737,
#  2817.1465586573054,
#  2936.4826012211693,
#  3056.3988090456796,
#  3177.2272329023403,
#  3298.5200686837497,
#  3420.377533366798,
#  3542.8554556408576,
#  3666.2522326237986,
#  3791.3263593935367,
#  3916.8620217342623,
#  4042.422766314672,
#  4168.91010697614,
#  4299.041802218694,
#  4430.518896024304,
#  4562.981943351239,
#  4696.033580486366,
#  4830.529168008309,
#  4965.993773224356,
#  5103.189115393598,
#  5242.347844105191,
# ...

# %% [markdown]
# Test Failed: 'Date[75 chars]01,207.15,200.49,207.15\n1972.02,318.78,303.99[20587 chars]59\n' != 'Date[75 chars]01,206.91,203.00,206.83\n1972.02,313.72,306.52[20590 chars]26\n'
# Diff is 43168 characters long. Set self.maxDiff to None to see it. : provided example: portfolio.csv does not match the expected contents

# %%
((206.91-100)/100-1)
# Out:
# 0.06909999999999994

# %%
a.dict_ROR['1971.12']["IndexROR"]+a.dict_ROR['1971.12']["Div"]/12
# Out:
# 0.06908758062206859

# %%
b.dict_ROR["1971.12"]
# Out:
# {'year': 1971, 'month': 12, 'Ror': 0.004941666666666666}

# %%
5.95
# Out:
# 1.0300187235213227

# %%
((307.52-100)/203-1)
# Out:
# 0.022266009852216717

# %%
(307-102.5)/203-1
# Out:
# 0.00738916256157629

# %%
307-102.5
# Out:
# 204.5

# %%
(313.72-102.5)/206.91
# Out:
# 1.0208303126963416

# %%
(a.dict_ROR['1972.01']["IndexROR"]+a.dict_ROR['1972.01']["Div"])/2
# Out:
# 0.022061132163006456

# %%
ans["StrategyOne"]
# Out:
# 0          100.00
# 1          206.91
# 2          313.72
# 3          424.42
# 4          532.25
#           ...
# 548    1669183.65
# 549    1697068.89
# 550    1743736.96
# 551    1771741.79
# 552    1823081.58
# Name: StrategyOne, Length: 553, dtype: float64

# %%
import pandas as pd
ans=pd.read_csv("example.csv")
[0]+[((ans["StrategyOne"][i]-100)/ans["StrategyOne"][i-1])-1 for i in range(1,len(ans["StrategyOne"]))]
# Out:
# [0,
#  0.06909999999999994,
#  0.032912860664056964,
#  0.03410684686982024,
#  0.01844870647000607,
#  -0.0030248943165805953,
#  0.009117721679563706,
#  -0.001629571286953846,
#  0.04075719297405378,
#  -0.009492071025453241,
#  0.0065469845193060205,
#  0.05458580769000054,
#  0.024964867322476714,
#  0.013341166344465805,
#  -0.029966780765684486,
#  -0.010318037616826814,
#  -0.01332681825849713,
#  -0.02279838323553318,
#  -0.017103000706111926,
#  0.014728359760852516,
#  -0.01382668154769151,
#  0.02230322209978053,
#  0.04451695863168359,
#  -0.06626050301184105,
#  -0.06571101107918198,
#  0.02025209797947114,
#  -0.021549808406106874,
#  0.04866235527686591,
#  -0.045211622335524226,
#  -0.024136585579310865,
#  0.0073555898160022615,
#  -0.11035235142618427,
#  -0.034581045238895824,
#  -0.09678392746048348,
#  0.02673368904310891,
#  0.040159434179538156,
#  -0.057973263267508734,
#  0.08967867231638404,
#  0.11097091309711016,
#  0.0524437288433639,
# ...

# %%
(1+0.04412226432601291)*100+100
# Out:
# 204.4122264326013

# %%
a.total_ROR_lst
# Out:
# [0.07145234707249602,
#  0.04412226432601291,
#  0.020824905801822575,
#  0.026139684119973583,
#  0.01256496548828437,
#  -0.007734868552806361,
#  0.005154342480828047,
#  -0.00502090243228304,
#  0.037760073506342126,
#  -0.012068284006126749,
#  0.004185209525969964,
#  0.05244862713265309,
#  0.023085476089247166,
#  0.009883673567184283,
#  -0.03316707688423981,
#  -0.013411584118100362,
#  -0.01627318033745998,
#  -0.025617605535333255,
#  -0.019827627131518047,
#  0.01209396960995107,
#  -0.016294407353582112,
#  0.019921532886670104,
#  0.04228487056355911,
#  -0.06830949319618554,
#  -0.0678125193947594,
#  0.01698050726690207,
#  -0.024626861309431182,
#  0.045638610603740415,
#  -0.047989908741436056,
#  -0.0269411303845587,
#  0.004586560368552857,
#  -0.11300770950876869,
#  -0.03745473302967857,
#  -0.09964612014444434,
#  0.02368584472553619,
#  0.037303887309395496,
#  -0.06062324193161626,
#  0.0860122574575966,
#  0.10771133886757672,
#  0.04959300546076772,
# ...
